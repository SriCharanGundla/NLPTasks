# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(binary = True)

# %%
#three documents
corpus = ["I have a German Shepherd", "German Shepherd is from Germany", "Germans love gossiping"]

# %%
vect.fit(corpus)
# Out:
# CountVectorizer(binary=True)

# %%
vocab = vect.vocabulary_

# %%
for key in sorted(vocab.keys()):
    print("{}:{}".format(key,vocab[key]))
# Out:
# from:0
# german:1
# germans:2
# germany:3
# gossiping:4
# have:5
# is:6
# love:7
# shepherd:8

# %%
print(vect.transform(["Germany has German Shepherd"]).toarray())
# Out:
# [[0 1 0 1 0 0 0 0 1]]

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vect.transform(["Germany has German Shepherd"]).toarray(), vect.transform(["Germany has Berlin as capital"]).toarray())

# %%
print(similarity)
# Out:
# [[0.57735027]]

# %%
#Lakshmi Sankaran Editorials' Cosine Similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(binary = True)

# %%
#editorials
e1 = "If there is a phrase I would prefer to retire from online bios, personal or professional, it is, “I love travel.” Or some approximation of that sentiment. To clarify, I am not against travellers or those who proudly flaunt their passion for travel. On the contrary, editing a travel magazine has now made me oddly protective of travellers and their ilk. My submission is that “love to travel,” suggested so casually, just doesn’t feel adequate to the depth of emotion it sparks in true devotees."
e2 = "Our year-end edition toasts ultra-indulgence while travelling, featuring itineraries that many will know to be out of their financial reach. In producing these narratives, I was struck by a contrast. Travel today is dominated by minimalists or downsizers, those who preach the gospel of “hard-knock wanderlust.” And they almost always reap universal admiration. They are characters to aspire to, examples of made-for-Instagram sayings such as, “All you need is a backpack” or “#MotorcycleDiaries.”"
e3 = "Every summer, the pastoral call of their motherland, Kerala, beckoned my parents. Their children would plead that they change direction at least for one year but these entreaties were dismissed as flakiness. Summer months were set in stone. And contrary to the breezy, game-for-anything attitude that the sun induced in many folks, for my mother and father, it was a season for constancy."
e4 = "J R.R. Tolkien was right to portray the Ents, hulking pieces of tall barks with sad eyes and mossy facial hair who guarded forests, as perhaps the most stoic figures in his Lord of the Rings trilogy. Their whole manner spoke to an endurance that seemed constantly on the verge of dissipation. They had seen and tolerated far too much in a world at war with itself. Yet they remained calm, like a steady lighthouse in torrential downpour."
e5 = "Once-in-a-lifetime is an overused expression in travel. Like everything else, the phrase has succumbed to a culture of instant hype. When every mountain hike, underwater dive or local meal is described with the glowing praise that should be meant for only the rarest of occurrences, it is difficult to tell a wonderful experience from a bucket list one. A bucket list just doesn’t translate with the same impact it was originally intended for."
e6 = "New and exciting has always received top billing in food—the latest fad, the newest restaurant, the trendiest neighbourhood, the healthiest diet. Often, these developments are accompanied by breathless pundit-like pronouncements: Lebanese is the new Chinese; Chinese is new Italian (wait, where does leave that Italian then?) A cuisine or dish has a moment, peaks and then becomes passé."
e7 = "n this modern agnostic world, pop culture is the closest thing we have to a shared religion. Matinee idols, artists and rock stars are our gods and goddesses, feeding us an endless supply of enchanting lore and myths. For this movement to thrive though, it needs fans; followers who have gone beyond aloof observation. Pop culture requires that fans click below to subscribe, not let it just play in the background."
e8 = "Part of the allure of a remote place is that the closer we get to it, the more we risk everything that made it precious. For years, Mount Everest inspired a sense of forbidden majesty, which was surmounted only by a few courageous adventurers. It helped that they were entertaining and we were content to immerse ourselves in the stories they wove from these monumental expeditions."
e9 = "The world’s greatest cities are brutal, unsentimental places, precisely the reason why so many of us fall so irrevocably under their spell. In its worst hour, this bond can curdle into bitter complaints of unrequited affection and everyday torment. “The subway doesn’t work, trash is overflowing and it’s too crowded; this is over.” Let me assure you that right now someone somewhere is uttering these words about your dream metropolis, New York, Rome, Rio De Janeiro. Like an unrepentant cad, the city laughs in their face, “Go on… live without me.” Wresting long-term connections comes with the occasional pang of nostalgic regret. Those who can’t escape their love of cities are destined to keep replaying that first flush of romance, that moment when a city went from a destination to home."
e10 = "As soon as a long, gleaming dark green train carriage, emblazoned with ‘Eastern & Oriental Express’ in engraved gold lettering slides into Hua Hin station, I feel a tinge of self-consciousness. Neither I nor my co-passengers from India are dressed for something this imperial. For the last hour, we have been milling about Hua Hin, Thailand’s oldest railway station—a quirky but fading royal artefact—in our baggy tees, jeans and dusty shoes, lugging backpacks and satchels. Once I hop aboard the train though, the air is less intimidating. While this is a majestic luxury locomotive boasting every accoutrement of refined sophistication, I see open, friendly faces in casual wear and summer hats."
e11 = "After a tiring snorkelling session in the clear waters of Koh Phangan, instructors Captain Pumpui and Captain Poo are shepherding me and five others on a private speedboat to nearby Bottle Beach for a picnic lunch of sandwiches, macarons and fruit juices. I am about 10-12 kilometres from Belmond Napasai’s lush tropical resort in Koh Samui, my home for the last day-and-a-half, and the sun is blindingly bright overhead. This is ideal snorkelling weather; we have had a field day gasping at eels and corals underwater. But the heat has stymied chatter on our boat."

# %%
edit_corpus = [e1,e2,e3,e4,e5,e6,e7,e8,e9,e10,e11] #corpus of editorials

# %%
vectorizer.fit(edit_corpus)
# Out:
# TfidfVectorizer(binary=True)

# %%
vocabulary = vectorizer.vocabulary_

# %%
for key in sorted(vocabulary.keys()):
    print("{}:{}".format(key,vocabulary[key]))
# Out:
# 10:0
# 12:1
# aboard:2
# about:3
# accompanied:4
# accoutrement:5
# adequate:6
# admiration:7
# adventurers:8
# affection:9
# after:10
# against:11
# agnostic:12
# air:13
# all:14
# allure:15
# almost:16
# aloof:17
# always:18
# am:19
# an:20
# and:21
# anything:22
# approximation:23
# are:24
# artefact:25
# artists:26
# as:27
# aspire:28
# assure:29
# at:30
# attitude:31
# background:32
# backpack:33
# backpacks:34
# baggy:35
# barks:36
# be:37
# beach:38
# beckoned:39
# becomes:40
# been:41
# belmond:42
# below:43
# beyond:44
# billing:45
# bios:46
# bitter:47
# blindingly:48
# boasting:49
# boat:50
# bond:51
# bottle:52
# breathless:53
# breezy:54
# bright:55
# brutal:56
# bucket:57
# but:58
# by:59
# cad:60
# call:61
# calm:62
# can:63
# captain:64
# carriage:65
# casual:66
# casually:67
# change:68
# characters:69
# chatter:70
# children:71
# chinese:72
# cities:73
# city:74
# clarify:75
# clear:76
# click:77
# closer:78
# closest:79
# co:80
# comes:81
# complaints:82
# connections:83
# consciousness:84
# constancy:85
# constantly:86
# content:87
# contrary:88
# contrast:89
# corals:90
# courageous:91
# crowded:92
# cuisine:93
# culture:94
# curdle:95
# dark:96
# day:97
# de:98
# depth:99
# described:100
# destination:101
# destined:102
# developments:103
# devotees:104
# diet:105
# difficult:106
# direction:107
# dish:108
# dismissed:109
# dissipation:110
# dive:111
# does:112
# doesn:113
# dominated:114
# downpour:115
# downsizers:116
# dream:117
# dressed:118
# dusty:119
# eastern:120
# editing:121
# edition:122
# eels:123
# else:124
# emblazoned:125
# emotion:126
# enchanting:127
# end:128
# endless:129
# endurance:130
# engraved:131
# entertaining:132
# entreaties:133
# ents:134
# escape:135
# everest:136
# every:137
# everyday:138
# everything:139
# examples:140
# exciting:141
# expeditions:142
# experience:143
# express:144
# expression:145
# eyes:146
# face:147
# faces:148
# facial:149
# fad:150
# fading:151
# fall:152
# fans:153
# far:154
# father:155
# featuring:156
# feeding:157
# feel:158
# few:159
# field:160
# figures:161
# financial:162
# first:163
# five:164
# flakiness:165
# flaunt:166
# flush:167
# folks:168
# followers:169
# food:170
# for:171
# forbidden:172
# forests:173
# friendly:174
# from:175
# fruit:176
# game:177
# gasping:178
# get:179
# gleaming:180
# glowing:181
# go:182
# goddesses:183
# gods:184
# gold:185
# gone:186
# gospel:187
# greatest:188
# green:189
# guarded:190
# had:191
# hair:192
# half:193
# hard:194
# has:195
# hats:196
# have:197
# healthiest:198
# heat:199
# helped:200
# hike:201
# hin:202
# his:203
# home:204
# hop:205
# hour:206
# hua:207
# hulking:208
# hype:209
# ideal:210
# idols:211
# if:212
# ilk:213
# immerse:214
# impact:215
# imperial:216
# in:217
# india:218
# induced:219
# indulgence:220
# inspired:221
# instagram:222
# instant:223
# instructors:224
# intended:225
# intimidating:226
# into:227
# irrevocably:228
# is:229
# it:230
# italian:231
# itineraries:232
# its:233
# itself:234
# janeiro:235
# jeans:236
# juices:237
# just:238
# keep:239
# kerala:240
# kilometres:241
# knock:242
# know:243
# koh:244
# last:245
# latest:246
# laughs:247
# least:248
# leave:249
# lebanese:250
# less:251
# let:252
# lettering:253
# lifetime:254
# lighthouse:255
# like:256
# list:257
# live:258
# local:259
# locomotive:260
# long:261
# lord:262
# lore:263
# love:264
# lugging:265
# lunch:266
# lush:267
# luxury:268
# macarons:269
# made:270
# magazine:271
# majestic:272
# majesty:273
# manner:274
# many:275
# matinee:276
# me:277
# meal:278
# meant:279
# metropolis:280
# milling:281
# minimalists:282
# modern:283
# moment:284
# months:285
# monumental:286
# more:287
# mossy:288
# most:289
# mother:290
# motherland:291
# motorcyclediaries:292
# mount:293
# mountain:294
# movement:295
# much:296
# my:297
# myths:298
# napasai:299
# narratives:300
# nearby:301
# need:302
# needs:303
# neighbourhood:304
# neither:305
# new:306
# newest:307
# nor:308
# nostalgic:309
# not:310
# now:311
# observation:312
# occasional:313
# occurrences:314
# oddly:315
# of:316
# often:317
# oldest:318
# on:319
# once:320
# one:321
# online:322
# only:323
# open:324
# or:325
# oriental:326
# originally:327
# others:328
# our:329
# ourselves:330
# out:331
# over:332
# overflowing:333
# overhead:334
# overused:335
# pang:336
# parents:337
# part:338
# passengers:339
# passion:340
# passé:341
# pastoral:342
# peaks:343
# perhaps:344
# personal:345
# phangan:346
# phrase:347
# picnic:348
# pieces:349
# place:350
# places:351
# play:352
# plead:353
# poo:354
# pop:355
# portray:356
# praise:357
# preach:358
# precious:359
# precisely:360
# prefer:361
# private:362
# producing:363
# professional:364
# pronouncements:365
# protective:366
# proudly:367
# pumpui:368
# pundit:369
# quirky:370
# railway:371
# rarest:372
# reach:373
# reap:374
# reason:375
# received:376
# refined:377
# regret:378
# religion:379
# remained:380
# remote:381
# replaying:382
# requires:383
# resort:384
# restaurant:385
# retire:386
# right:387
# rings:388
# rio:389
# risk:390
# rock:391
# romance:392
# rome:393
# royal:394
# sad:395
# same:396
# samui:397
# sandwiches:398
# satchels:399
# sayings:400
# season:401
# see:402
# seemed:403
# seen:404
# self:405
# sense:406
# sentiment:407
# session:408
# set:409
# shared:410
# shepherding:411
# shoes:412
# should:413
# slides:414
# snorkelling:415
# so:416
# some:417
# someone:418
# something:419
# somewhere:420
# soon:421
# sophistication:422
# sparks:423
# speedboat:424
# spell:425
# spoke:426
# stars:427
# station:428
# steady:429
# stoic:430
# stone:431
# stories:432
# struck:433
# stymied:434
# submission:435
# subscribe:436
# subway:437
# succumbed:438
# such:439
# suggested:440
# summer:441
# sun:442
# supply:443
# surmounted:444
# tall:445
# tees:446
# tell:447
# term:448
# thailand:449
# that:450
# the:451
# their:452
# then:453
# there:454
# these:455
# they:456
# thing:457
# this:458
# those:459
# though:460
# thrive:461
# tinge:462
# tiring:463
# to:464
# toasts:465
# today:466
# tolerated:467
# tolkien:468
# too:469
# top:470
# torment:471
# torrential:472
# train:473
# translate:474
# trash:475
# travel:476
# travellers:477
# travelling:478
# trendiest:479
# trilogy:480
# tropical:481
# true:482
# ultra:483
# under:484
# underwater:485
# universal:486
# unrepentant:487
# unrequited:488
# unsentimental:489
# us:490
# uttering:491
# verge:492
# wait:493
# wanderlust:494
# war:495
# was:496
# waters:497
# we:498
# wear:499
# weather:500
# went:501
# were:502
# when:503
# where:504
# which:505
# while:506
# who:507
# whole:508
# why:509
# will:510
# with:511
# without:512
# wonderful:513
# words:514
# work:515
# world:516
# worst:517
# would:518
# wove:519
# wresting:520
# year:521
# years:522
# yet:523
# york:524
# you:525
# your:526

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
#latest two editorials to test the similarity
new1 = "In a bid to ease paperwork for millions of tourists, the EU has proposed to make the Schengen visa process an online application system in the next few years. The Schengen visa allows travellers to visit and travel across 26 EU member nations for up to 90 days. Right now, tourists submit their visa application to a country’s local consulate and collect their passports in person once the visa is issued—a time-consuming process which became complicated during the last two years of the pandemic. The new proposal envisions a single digital visa application platform for all EU countries. Instead of a physical sticker, the visa is expected to be a cryptographically signed 2D bar code."
new2 = "Travellers can now fly directly between Pune and Singapore starting December 2, courtesy Vistara which will kick off three to four flights every week. International connections from Pune are rare (right now, Dubai is the sole one); visitors normally rely on Mumbai airport for the same. However, authorities are now planning to connect the city to two more Southeast Asian countries once the Singapore route is up and running."

# %%
for i in range(11):
    e = edit_corpus[i]
    print(cosine_similarity(vectorizer.transform([e]).toarray(), vectorizer.transform([new1]).toarray()))
# Out:
# [[0.20547244]]
# [[0.1397662]]
# [[0.05631726]]
# [[0.08456492]]
# [[0.19708135]]
# [[0.07622767]]
# [[0.06266788]]
# [[0.17958218]]
# [[0.11139023]]
# [[0.07254649]]
# [[0.07776629]]

# %%
for i in range(11):
    e = edit_corpus[i]
    print(cosine_similarity(vectorizer.transform([e]).toarray(), vectorizer.transform([new2]).toarray()))
# Out:
# [[0.13527275]]
# [[0.08215362]]
# [[0.0869016]]
# [[0.0627526]]
# [[0.16745744]]
# [[0.03402452]]
# [[0.04734491]]
# [[0.14194734]]
# [[0.18068758]]
# [[0.08013157]]
# [[0.06647033]]
